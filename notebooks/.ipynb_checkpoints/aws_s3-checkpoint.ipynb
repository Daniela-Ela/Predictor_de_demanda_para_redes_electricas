# %%
# !pip install boto3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.6 MB/s eta 0:00:00
# ...

# %%
import boto3

try:
    s3 = boto3.client('s3')
    buckets = s3.list_buckets()
    print("¡Conexión exitosa!")
    print(f"Tienes {len(buckets['Buckets'])} buckets en tu cuenta.")
except Exception as e:
    print("Error de conexión. Revisa tus credenciales.")
    print(e)
# Out:
# ¡Conexión exitosa!
# Tienes 2 buckets en tu cuenta.

# %%
bucket_name = "proyecto-electricidad-ela"

response = s3.list_objects_v2(Bucket=bucket_name)

for obj in response.get('Contents', []):
    print(obj['Key'])
# Out:
# bronze/
# bronze/calendario/
# bronze/clima/
# bronze/ree/
# bronze/ree/ree_raw_2019_01.json

# %%
import boto3

s3 = boto3.client("s3")

bucket_name = "proyecto-electricidad-ela"
key = "bronze/ree/ree_raw_2019_01.json"

# descargar
s3.download_file(bucket_name, key, "../data/bronze/ree_from_s3.json")

print("Descargado correctamente")
# Out:
# Descargado correctamente
