# %%
import json
import requests
from pathlib import Path

# %%
YEARS = [2024, 2025]
COUNTRY = "ES"

output_dir = Path("../data/bronze/festivos")
output_dir.mkdir(parents=True, exist_ok=True)

print("Carpeta creada:", output_dir)
# Out:
# Carpeta creada: ../data/bronze/festivos
